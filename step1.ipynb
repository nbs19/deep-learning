# %% [markdown]
# <a href="https://colab.research.google.com/github/nbs19/deep-learning/blob/main/step1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# mobile_cleaned.csv  sample_data

# %%
import pandas as pd

# %%
df=pd.read_csv('mobile_cleaned.csv')
df.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# 108         2         8         3  ...              3000               2         0
#
# [5 rows x 40 columns]

# %%
dir(df)
# Out:
# ['FM',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
len(df)
# Out:
# 109

# %%
df.shape
# Out:
# (109, 40)

# %%
df.loc[10]
# Out:
# sim_type                                0.0
# aperture                                1.0
# gpu_rank                               55.0
# weight                                169.0
# stand_by_time                         514.0
# processor_frequency                     1.3
# thickness                               7.9
# flash_type                              2.0
# front_camera_resolution                 2.0
# auto_focus                              3.0
# screen_size                             5.0
# frames_per_second                      30.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       5.0
# os                                      0.0
# phone_height                          152.0
# screen_protection                      26.0
# sim_size                                3.0
# price                                6749.0
# talk_time                              14.0
# video_resolution                      720.0
# ...

# %%
df_short=df[0:15]
df.shape
df.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
df_thin=df[['stand_by_time','expandable_memory','price','battery_capacity','is_liked']]
df_thin.head()
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
df_liked=df[df['is_liked']==1]
print(df_liked)
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0           0        12        55  ...              2000             125         1
# 1           0         1        55  ...              2000             165         1
# 3           0         8        55  ...              3000             165         1
# 6           1         1        56  ...              1700             163         1
# 7           0         8        41  ...              2000              92         1
# ..        ...       ...       ...  ...               ...             ...       ...
# 103         3         8         9  ...              3430               5         1
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# ...

# %%
df['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df['price'].mean()
# Out:
# 19373.211009174312

# %%
df_thin[df_thin['is_liked']==1]['price'].mean()
# Out:
# 19393.239130434784

# %%
g=df_thin.groupby(['is_liked'])
for key, kay in g:
  print(key)
  print(kay)
# Out:
# 0
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 2              329               32.0   4777              2500         0
# 4              385               32.0   5990              3000         0
# 5              280               32.0   5999              2900         0
# 11             300              128.0   6990              2600         0
# 22             354              128.0   7999              2400         0
# 38             490               32.0   9999              2100         0
# 53             345               64.0  14300              2950         0
# 60             840                0.0  15689              4100         0
# 74             390              128.0  21999              2800         0
# 77             620              128.0  22999              3100         0
# 78             618                0.0  24499              3600         0
# 80             598                0.0  24999              3000         0
# ...
